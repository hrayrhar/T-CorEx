# %%
import json

# %%
data = json.loads('''{
  "Ledoit-Wolf": {
    "std": 0.0,
    "min": 169.1687751239739,
    "best_params": {
      
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 183.1851945750339,
          "scores": [
            183.1851945750339
          ],
          "mean": 183.1851945750339
        },
        "min": 180.53645831673515,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 4,
        "scores": [
          180.53645831673515
        ],
        "mean": 180.53645831673515
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 178.11232654663,
          "scores": [
            178.11232654663
          ],
          "mean": 178.11232654663
        },
        "min": 173.0716365324322,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 8,
        "scores": [
          173.0716365324322
        ],
        "mean": 173.0716365324322
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 164.54947920874469,
          "scores": [
            164.54947920874469
          ],
          "mean": 164.54947920874469
        },
        "min": 169.38369683605666,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 12,
        "scores": [
          169.38369683605666
        ],
        "mean": 169.38369683605666
      }
    ],
    "best_window": 12,
    "scores": [
      169.1687751239739
    ],
    "mean": 169.1687751239739
  },
  "Ground Truth": {
    "std": 0.0,
    "min": 125.01186181029632,
    "best_params": {
      
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 125.01186181029632,
          "scores": [
            125.01186181029632
          ],
          "mean": 125.01186181029632
        },
        "min": 125.01186181029632,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 4,
        "scores": [
          125.01186181029632
        ],
        "mean": 125.01186181029632
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 125.01186181029632,
          "scores": [
            125.01186181029632
          ],
          "mean": 125.01186181029632
        },
        "min": 125.01186181029632,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 8,
        "scores": [
          125.01186181029632
        ],
        "mean": 125.01186181029632
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 125.01186181029632,
          "scores": [
            125.01186181029632
          ],
          "mean": 125.01186181029632
        },
        "min": 125.01186181029632,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 12,
        "scores": [
          125.01186181029632
        ],
        "mean": 125.01186181029632
      }
    ],
    "best_window": 4,
    "scores": [
      125.01186181029632
    ],
    "mean": 125.01186181029632
  },
  "Linear CorEx": {
    "std": 0.0,
    "min": 153.63700479947286,
    "best_params": {
      "anneal": true,
      "max_iter": 500,
      "n_hidden": 8
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 247.34933297033632,
        "min": 224.48984185467637,
        "cur_best_params": {
          "anneal": true,
          "max_iter": 500,
          "n_hidden": 8
        },
        "stride": "one",
        "window": 4,
        "scores": [
          224.48984185467637
        ],
        "mean": 224.48984185467637
      },
      {
        "std": 0.0,
        "cur_best_val_score": 157.8713160608514,
        "min": 165.5109748454673,
        "cur_best_params": {
          "anneal": true,
          "max_iter": 500,
          "n_hidden": 8
        },
        "stride": "one",
        "window": 8,
        "scores": [
          165.5109748454673
        ],
        "mean": 165.5109748454673
      },
      {
        "std": 0.0,
        "cur_best_val_score": 142.67490356671343,
        "min": 154.09236496967992,
        "cur_best_params": {
          "anneal": true,
          "max_iter": 500,
          "n_hidden": 8
        },
        "stride": "one",
        "window": 12,
        "scores": [
          154.09236496967992
        ],
        "mean": 154.09236496967992
      }
    ],
    "best_window": 12,
    "scores": [
      153.63700479947286
    ],
    "mean": 153.63700479947286
  },
  "Graphical LASSO": {
    "std": 0.0,
    "min": 154.49621474002484,
    "best_params": {
      "alpha": 0.3,
      "max_iter": 100,
      "mode": "lars"
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 203.24681258775237,
        "min": 194.52705844523223,
        "cur_best_params": {
          "alpha": 1,
          "max_iter": 100,
          "mode": "lars"
        },
        "stride": "one",
        "window": 4,
        "scores": [
          194.52705844523223
        ],
        "mean": 194.52705844523223
      },
      {
        "std": 0.0,
        "cur_best_val_score": 165.5405535550192,
        "min": 162.0888431677895,
        "cur_best_params": {
          "alpha": 0.3,
          "max_iter": 100,
          "mode": "lars"
        },
        "stride": "one",
        "window": 8,
        "scores": [
          162.0888431677895
        ],
        "mean": 162.0888431677895
      },
      {
        "std": 0.0,
        "cur_best_val_score": 157.88918744044497,
        "min": 155.28328044743736,
        "cur_best_params": {
          "alpha": 0.3,
          "max_iter": 100,
          "mode": "lars"
        },
        "stride": "one",
        "window": 12,
        "scores": [
          155.28328044743736
        ],
        "mean": 155.28328044743736
      }
    ],
    "best_window": 12,
    "scores": [
      154.49621474002484
    ],
    "mean": 154.49621474002484
  },
  "Time-Varying GLASSO (no reg)": {
    "std": 0.0,
    "min": 159.76703554428764,
    "best_params": {
      "lamb": 0.3,
      "beta": 0.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "best_stride": "half",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 186.83702549284916,
        "min": 183.70044010291977,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 4,
        "scores": [
          183.70044010291977
        ],
        "mean": 183.70044010291977
      },
      {
        "std": 0.0,
        "cur_best_val_score": 183.35373980868584,
        "min": 183.48446272368702,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "half",
        "window": 4,
        "scores": [
          183.48446272368702
        ],
        "mean": 183.48446272368702
      },
      {
        "std": 0.0,
        "cur_best_val_score": 186.90912769025627,
        "min": 184.24149789176832,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "full",
        "window": 4,
        "scores": [
          184.24149789176832
        ],
        "mean": 184.24149789176832
      },
      {
        "std": 0.0,
        "cur_best_val_score": 156.66726639401764,
        "min": 161.85970905795662,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 8,
        "scores": [
          161.85970905795662
        ],
        "mean": 161.85970905795662
      },
      {
        "std": 0.0,
        "cur_best_val_score": 152.8485450871674,
        "min": 160.8308608562145,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "half",
        "window": 8,
        "scores": [
          160.8308608562145
        ],
        "mean": 160.8308608562145
      },
      {
        "std": 0.0,
        "cur_best_val_score": 165.71350676032566,
        "min": 155.7276411303376,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.0,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 12,
        "scores": [
          155.7276411303376
        ],
        "mean": 155.7276411303376
      }
    ],
    "best_window": 8,
    "scores": [
      159.76703554428764
    ],
    "mean": 159.76703554428764
  },
  "Time-Varying Linear CorEx (Sigma)": {
    "std": 0.0,
    "min": 153.4601835099869,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.01,
      "anneal": true,
      "nt": 30,
      "n_hidden": 8,
      "nv": 128
    },
    "best_stride": "half",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 198.23800981114329,
        "min": 203.63331217744542,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 10.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 4,
        "scores": [
          203.63331217744542
        ],
        "mean": 203.63331217744542
      },
      {
        "std": 0.0,
        "cur_best_val_score": 186.89653976862664,
        "min": 202.79893918392955,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.001,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 4,
        "scores": [
          202.79893918392955
        ],
        "mean": 202.79893918392955
      },
      {
        "std": 0.0,
        "cur_best_val_score": 199.86379303960643,
        "min": 201.0075547095455,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "full",
        "window": 4,
        "scores": [
          201.0075547095455
        ],
        "mean": 201.0075547095455
      },
      {
        "std": 0.0,
        "cur_best_val_score": 166.8320373853184,
        "min": 164.51336006548132,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 8,
        "scores": [
          164.51336006548132
        ],
        "mean": 164.51336006548132
      },
      {
        "std": 0.0,
        "cur_best_val_score": 137.55131141818077,
        "min": 155.32957549835362,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.01,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 8,
        "scores": [
          155.32957549835362
        ],
        "mean": 155.32957549835362
      },
      {
        "std": 0.0,
        "cur_best_val_score": 165.98555375045984,
        "min": 154.65795474413315,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.01,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 12,
        "scores": [
          154.65795474413315
        ],
        "mean": 154.65795474413315
      }
    ],
    "best_window": 8,
    "scores": [
      153.4601835099869
    ],
    "mean": 153.4601835099869
  },
  "Factor Analysis": {
    "std": 0.0,
    "min": 200.23894133649398,
    "best_params": {
      "n_components": 8
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": NaN,
        "cur_best_val_score": 1e+18,
        "min": Infinity,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 4,
        "scores": [
          Infinity
        ],
        "mean": Infinity
      },
      {
        "std": 0.0,
        "cur_best_val_score": 551.2944138311221,
        "min": 451.4300144075715,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 8,
        "scores": [
          451.4300144075715
        ],
        "mean": 451.4300144075715
      },
      {
        "std": 0.0,
        "cur_best_val_score": 194.91576801573447,
        "min": 206.38163500578426,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 12,
        "scores": [
          206.38163500578426
        ],
        "mean": 206.38163500578426
      }
    ],
    "best_window": 12,
    "scores": [
      200.23894133649398
    ],
    "mean": 200.23894133649398
  },
  "Oracle approximating shrinkage": {
    "std": 0.0,
    "min": 169.24618415079541,
    "best_params": {
      
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 183.03820917635704,
          "scores": [
            183.03820917635704
          ],
          "mean": 183.03820917635704
        },
        "min": 176.59441063830187,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 4,
        "scores": [
          176.59441063830187
        ],
        "mean": 176.59441063830187
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 170.05539891339558,
          "scores": [
            170.05539891339558
          ],
          "mean": 170.05539891339558
        },
        "min": 172.71040454818325,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 8,
        "scores": [
          172.71040454818325
        ],
        "mean": 172.71040454818325
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 162.49985855480946,
          "scores": [
            162.49985855480946
          ],
          "mean": 162.49985855480946
        },
        "min": 169.39965590880055,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 12,
        "scores": [
          169.39965590880055
        ],
        "mean": 169.39965590880055
      }
    ],
    "best_window": 12,
    "scores": [
      169.24618415079541
    ],
    "mean": 169.24618415079541
  },
  "Diagonal": {
    "std": 0.0,
    "min": 184.8714681844925,
    "best_params": {
      
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 190.1331914799665,
          "scores": [
            190.1331914799665
          ],
          "mean": 190.1331914799665
        },
        "min": 196.69555476538474,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 4,
        "scores": [
          196.69555476538474
        ],
        "mean": 196.69555476538474
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 199.81042186690064,
          "scores": [
            199.81042186690064
          ],
          "mean": 199.81042186690064
        },
        "min": 187.1910667321898,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 8,
        "scores": [
          187.1910667321898
        ],
        "mean": 187.1910667321898
      },
      {
        "std": 0.0,
        "cur_best_val_score": {
          "std": 0.0,
          "min": 189.527861967616,
          "scores": [
            189.527861967616
          ],
          "mean": 189.527861967616
        },
        "min": 184.9282762184367,
        "cur_best_params": {
          
        },
        "stride": "one",
        "window": 12,
        "scores": [
          184.9282762184367
        ],
        "mean": 184.9282762184367
      }
    ],
    "best_window": 12,
    "scores": [
      184.8714681844925
    ],
    "mean": 184.8714681844925
  },
  "Time-Varying Linear CorEx (WWT)": {
    "std": 0.0,
    "min": 153.36900796175186,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0,
      "anneal": true,
      "nt": 30,
      "n_hidden": 8,
      "nv": 128
    },
    "best_stride": "half",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 208.17358511429302,
        "min": 204.69685383629158,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 3.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 4,
        "scores": [
          204.69685383629158
        ],
        "mean": 204.69685383629158
      },
      {
        "std": 0.0,
        "cur_best_val_score": 205.5487925499208,
        "min": 200.51577006193847,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 3.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 4,
        "scores": [
          200.51577006193847
        ],
        "mean": 200.51577006193847
      },
      {
        "std": 0.0,
        "cur_best_val_score": 160.54486667243893,
        "min": 195.20550452984617,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 1.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "full",
        "window": 4,
        "scores": [
          195.20550452984617
        ],
        "mean": 195.20550452984617
      },
      {
        "std": 0.0,
        "cur_best_val_score": 160.766871320407,
        "min": 163.4240113056025,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.03,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 8,
        "scores": [
          163.4240113056025
        ],
        "mean": 163.4240113056025
      },
      {
        "std": 0.0,
        "cur_best_val_score": 140.23427902796664,
        "min": 157.32120931458326,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 8,
        "scores": [
          157.32120931458326
        ],
        "mean": 157.32120931458326
      },
      {
        "std": 0.0,
        "cur_best_val_score": 155.91597550457152,
        "min": 154.49019207675937,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.03,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 12,
        "scores": [
          154.49019207675937
        ],
        "mean": 154.49019207675937
      }
    ],
    "best_window": 8,
    "scores": [
      153.36900796175186
    ],
    "mean": 153.36900796175186
  },
  "Time-Varying Linear CorEx (W)": {
    "std": 0.0,
    "min": 153.2804736474282,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.03,
      "anneal": true,
      "nt": 30,
      "n_hidden": 8,
      "nv": 128
    },
    "best_stride": "half",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 210.06528688521283,
        "min": 204.53452902019106,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 3.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 4,
        "scores": [
          204.53452902019106
        ],
        "mean": 204.53452902019106
      },
      {
        "std": 0.0,
        "cur_best_val_score": 228.26137237835428,
        "min": 203.207371229284,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 3.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 4,
        "scores": [
          203.207371229284
        ],
        "mean": 203.207371229284
      },
      {
        "std": 0.0,
        "cur_best_val_score": 161.8378571518444,
        "min": 188.67096730955612,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.1,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "full",
        "window": 4,
        "scores": [
          188.67096730955612
        ],
        "mean": 188.67096730955612
      },
      {
        "std": 0.0,
        "cur_best_val_score": 171.08814557466863,
        "min": 167.67896194391946,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 3.0,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 8,
        "scores": [
          167.67896194391946
        ],
        "mean": 167.67896194391946
      },
      {
        "std": 0.0,
        "cur_best_val_score": 147.34274425345293,
        "min": 153.55624962223862,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.03,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "half",
        "window": 8,
        "scores": [
          153.55624962223862
        ],
        "mean": 153.55624962223862
      },
      {
        "std": 0.0,
        "cur_best_val_score": 175.50059222618032,
        "min": 154.22669005522823,
        "cur_best_params": {
          "max_iter": 500,
          "l2": 0,
          "l1": 0.3,
          "anneal": true,
          "nt": 30,
          "n_hidden": 8,
          "nv": 128
        },
        "stride": "one",
        "window": 12,
        "scores": [
          154.22669005522823
        ],
        "mean": 154.22669005522823
      }
    ],
    "best_window": 8,
    "scores": [
      153.2804736474282
    ],
    "mean": 153.2804736474282
  },
  "Time-Varying GLASSO": {
    "std": 0.0,
    "min": 209.3276772151681,
    "best_params": {
      "lamb": 0.01,
      "beta": 0.3,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": 0.0,
        "cur_best_val_score": 88.24408678162969,
        "min": 216.05504027838072,
        "cur_best_params": {
          "lamb": 0.01,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 4,
        "scores": [
          216.05504027838072
        ],
        "mean": 216.05504027838072
      },
      {
        "std": 0.0,
        "cur_best_val_score": 133.42601383997342,
        "min": 209.3006449212958,
        "cur_best_params": {
          "lamb": 0.01,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "half",
        "window": 4,
        "scores": [
          209.3006449212958
        ],
        "mean": 209.3006449212958
      },
      {
        "std": 0.0,
        "cur_best_val_score": 165.6113098942964,
        "min": 156.61602772015922,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "full",
        "window": 4,
        "scores": [
          156.61602772015922
        ],
        "mean": 156.61602772015922
      },
      {
        "std": 0.0,
        "cur_best_val_score": 81.77847456932496,
        "min": 210.01353938830655,
        "cur_best_params": {
          "lamb": 0.01,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 8,
        "scores": [
          210.01353938830655
        ],
        "mean": 210.01353938830655
      },
      {
        "std": 0.0,
        "cur_best_val_score": 147.62071588476806,
        "min": 155.385618281756,
        "cur_best_params": {
          "lamb": 0.3,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "half",
        "window": 8,
        "scores": [
          155.385618281756
        ],
        "mean": 155.385618281756
      },
      {
        "std": 0.0,
        "cur_best_val_score": 91.67393625556444,
        "min": 206.76296251631393,
        "cur_best_params": {
          "lamb": 0.01,
          "beta": 0.3,
          "max_iter": 30,
          "indexOfPenalty": 1
        },
        "stride": "one",
        "window": 12,
        "scores": [
          206.76296251631393
        ],
        "mean": 206.76296251631393
      }
    ],
    "best_window": 8,
    "scores": [
      209.3276772151681
    ],
    "mean": 209.3276772151681
  },
  "PCA": {
    "std": 0.0,
    "min": 200.52944987142465,
    "best_params": {
      "n_components": 8
    },
    "best_stride": "one",
    "results_per_window_and_stride": [
      {
        "std": NaN,
        "cur_best_val_score": 1e+18,
        "min": Infinity,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 4,
        "scores": [
          Infinity
        ],
        "mean": Infinity
      },
      {
        "std": 0.0,
        "cur_best_val_score": 212.6357441217853,
        "min": 211.85876629210537,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 8,
        "scores": [
          211.85876629210537
        ],
        "mean": 211.85876629210537
      },
      {
        "std": 0.0,
        "cur_best_val_score": 204.69510516762531,
        "min": 201.69017715202088,
        "cur_best_params": {
          "n_components": 8
        },
        "stride": "one",
        "window": 12,
        "scores": [
          201.69017715202088
        ],
        "mean": 201.69017715202088
      }
    ],
    "best_window": 12,
    "scores": [
      200.52944987142465
    ],
    "mean": 200.52944987142465
  }
}''')

# %%
for k,v in data.items():
    print "{:<40} {:.2f}".format(k, v['mean'])
# Out:
# Ledoit-Wolf                              169.17
# Ground Truth                             125.01
# Linear CorEx                             153.64
# Time-Varying Linear CorEx (Sigma)        153.46
# Time-Varying GLASSO (no reg)             159.77
# Graphical LASSO                          154.50
# Oracle approximating shrinkage           169.25
# Time-Varying Linear CorEx (W)            153.28
# Time-Varying Linear CorEx (WWT)          153.37
# Diagonal                                 184.87
# Time-Varying GLASSO                      209.33
# PCA                                      200.53
# Factor Analysis                          200.24

# %%
data = json.loads(
'''
{
  "Ground Truth": {
    "std": 0.0,
    "best_params": {
      
    },
    "min": 84.907758484804518,
    "scores": [
      84.907758484804518
    ],
    "mean": 84.907758484804518
  },
  "Linear CorEx": {
    "std": 0.0,
    "best_params": {
      "anneal": "True",
      "max_iter": 500,
      "n_hidden": 8
    },
    "min": 99.721302082114931,
    "scores": [
      99.721302082114931
    ],
    "mean": 99.721302082114931
  },
  "Time-Varying Linear CorEx (Sigma)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.03,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 98.63976356281637,
    "scores": [
      98.63976356281637
    ],
    "mean": 98.63976356281637
  },
  "Time-Varying GLASSO (no reg)": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.1,
      "beta": 0.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 110.71448230952464,
    "scores": [
      110.71448230952464
    ],
    "mean": 110.71448230952464
  },
  "Time-Varying Linear CorEx (no reg)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.0,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 99.484795303340519,
    "scores": [
      99.484795303340519
    ],
    "mean": 99.484795303340519
  },
  "Time-Varying Linear CorEx (WWT)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.003,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 99.141739287341835,
    "scores": [
      99.141739287341835
    ],
    "mean": 99.141739287341835
  },
  "Time-Varying Linear CorEx (W)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 1.0,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 99.078204006803929,
    "scores": [
      99.078204006803929
    ],
    "mean": 99.078204006803929
  },
  "Time-Varying GLASSO": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.03,
      "beta": 1.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 96.340537292882615,
    "scores": [
      96.340537292882615
    ],
    "mean": 96.340537292882615
  },
  "Linear CorEx on whole data": {
    "std": 0.0,
    "min": 87.096029800351829,
    "scores": [
      87.096029800351829
    ],
    "mean": 87.096029800351829
  },
  "GLASSO on whole data": {
    "std": 0.0,
    "min": 94.055079514040386,
    "scores": [
      94.055079514040386
    ],
    "mean": 94.055079514040386
  }
}
''')

# %%
for k,v in data.items():
    print "{:<40} {:.2f}".format(k, v['mean'])
# Out:
# Ground Truth                             84.91
# Linear CorEx                             99.72
# Linear CorEx on whole data               87.10
# Time-Varying Linear CorEx (Sigma)        98.64
# Time-Varying GLASSO (no reg)             110.71
# Time-Varying Linear CorEx (no reg)       99.48
# Time-Varying Linear CorEx (WWT)          99.14
# Time-Varying Linear CorEx (W)            99.08
# Time-Varying GLASSO                      96.34
# GLASSO on whole data                     94.06

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
keys = [k for k,v in data.items()]
values = [v['mean'] for k,v in data.items()]
mas = sorted(zip(keys, values))
keys = [x[0] for x in mas]
values = [x[1] for x in mas]


plt.figure(figsize=(12, 6), dpi=800)
plt.bar(range(len(keys)), values, width=0.6)
plt.ylim(0.9*data['Ground Truth']['mean'])
plt.xticks(range(len(keys)), keys, rotation=90)
for i, v in enumerate(values):
    plt.text(i - 0.4, v+1, '{:.2f}'.format(v))
plt.tight_layout()
plt.title('m=8, bs=16, ns=16')
plt.subplots_adjust(top=0.9)
plt.show()

# %%
data = json.loads('''
{
  "Ground Truth": {
    "std": 0.0,
    "best_params": {
      
    },
    "min": 84.55060180606786,
    "scores": [
      84.55060180606786
    ],
    "mean": 84.55060180606786
  },
  "Linear CorEx": {
    "std": 0.0,
    "best_params": {
      "anneal": "True",
      "max_iter": 500,
      "n_hidden": 8
    },
    "min": 160.32539373744984,
    "scores": [
      160.32539373744984
    ],
    "mean": 160.32539373744984
  },
  "Time-Varying Linear CorEx (Sigma)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.03,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 149.86821607613717,
    "scores": [
      149.86821607613717
    ],
    "mean": 149.86821607613717
  },
  "Time-Varying GLASSO (no reg)": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.3,
      "beta": 0.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 142.37479648741169,
    "scores": [
      142.37479648741169
    ],
    "mean": 142.37479648741169
  },
  "Time-Varying Linear CorEx (no reg)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.0,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 155.93288624398002,
    "scores": [
      155.93288624398002
    ],
    "mean": 155.93288624398002
  },
  "Time-Varying Linear CorEx (WWT)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.03,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 145.90582104589581,
    "scores": [
      145.90582104589581
    ],
    "mean": 145.90582104589581
  },
  "Time-Varying Linear CorEx (W)": {
    "std": 0.0,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.3,
      "anneal": "True",
      "nt": 5,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 151.89389088445782,
    "scores": [
      151.89389088445782
    ],
    "mean": 151.89389088445782
  },
  "Time-Varying GLASSO": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.1,
      "beta": 1.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 100.65529177359527,
    "scores": [
      100.65529177359527
    ],
    "mean": 100.65529177359527
  },
  "Linear CorEx on whole data": {
    "std": 0.0,
    "min": 88.537798848726183,
    "scores": [
      88.537798848726183
    ],
    "mean": 88.537798848726183
  },
  "GLASSO on whole data": {
    "std": 0.0,
    "min": 97.231055199965667,
    "scores": [
      97.231055199965667
    ],
    "mean": 97.231055199965667
  }
}
''')

# %%
for k,v in data.items():
    print "{:<40} {:.2f}".format(k, v['mean'])
# Out:
# Ground Truth                             84.55
# Linear CorEx                             160.33
# Linear CorEx on whole data               88.54
# Time-Varying Linear CorEx (Sigma)        149.87
# Time-Varying GLASSO (no reg)             142.37
# Time-Varying Linear CorEx (no reg)       155.93
# Time-Varying Linear CorEx (WWT)          145.91
# Time-Varying Linear CorEx (W)            151.89
# Time-Varying GLASSO                      100.66
# GLASSO on whole data                     97.23

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
keys = [k for k,v in data.items()]
values = [v['mean'] for k,v in data.items()]
mas = sorted(zip(keys, values))
keys = [x[0] for x in mas]
values = [x[1] for x in mas]


plt.figure(figsize=(12, 6), dpi=800)
plt.bar(range(len(keys)), values, width=0.6)
plt.ylim(0.9*data['Ground Truth']['mean'])
plt.xticks(range(len(keys)), keys, rotation=90)
for i, v in enumerate(values):
    plt.text(i - 0.4, v+1, '{:.2f}'.format(v))
plt.tight_layout()
plt.title('m=8, bs=16, ns=8')
plt.subplots_adjust(top=0.9)
plt.show()
