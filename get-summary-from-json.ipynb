# %%
import json

# %%
data = json.loads('''{
  "Time-Varying GLASSO": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.03,
      "beta": 0.3,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 97.67523883314381,
    "scores": [
      97.67523883314381,
      97.67523883314381,
      97.67523883314381,
      97.67523883314381,
      97.67523883314381
    ],
    "mean": 97.67523883314381
  },
  "Ledoit-Wolf": {
    "std": 0.0,
    "best_params": {
     
    },
    "min": 125.59693536535777,
    "scores": [
      125.59693536535777,
      125.59693536535777,
      125.59693536535777,
      125.59693536535777,
      125.59693536535777
    ],
    "mean": 125.59693536535777
  },
  "Ground Truth": {
    "std": 0.0,
    "best_params": {
     
    },
    "min": 84.3658506438633,
    "scores": [
      84.3658506438633,
      84.3658506438633,
      84.3658506438633,
      84.3658506438633,
      84.3658506438633
    ],
    "mean": 84.3658506438633
  },
  "Linear CorEx": {
    "std": 0.004882653204004351,
    "best_params": {
      "anneal": true,
      "max_iter": 500,
      "n_hidden": 8
    },
    "min": 100.47132679351712,
    "scores": [
      100.4804225280343,
      100.47913141129813,
      100.47842623426786,
      100.47132679351712,
      100.48662408844808
    ],
    "mean": 100.4791862111131
  },
  "Graphical LASSO": {
    "std": 0.0,
    "best_params": {
      "alpha": 1,
      "max_iter": 100,
      "mode": "lars"
    },
    "min": 180.3578295520472,
    "scores": [
      180.3578295520472,
      180.3578295520472,
      180.3578295520472,
      180.3578295520472,
      180.3578295520472
    ],
    "mean": 180.3578295520472
  },
  "Time-Varying GLASSO (no reg)": {
    "std": 0.0,
    "best_params": {
      "lamb": 0.1,
      "beta": 0.0,
      "max_iter": 30,
      "indexOfPenalty": 1
    },
    "min": 110.36050146489171,
    "scores": [
      110.36050146489171,
      110.36050146489171,
      110.36050146489171,
      110.36050146489171,
      110.36050146489171
    ],
    "mean": 110.36050146489171
  },
  "Time-Varying Linear CorEx (Sigma)": {
    "std": 0.011220155475647297,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.03,
      "anneal": true,
      "nt": 10,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 98.51866933056644,
    "scores": [
      98.53223021893385,
      98.52890979922395,
      98.53049048678436,
      98.51866933056644,
      98.55302578599915
    ],
    "mean": 98.53266512430154
  },
  "Factor Analysis": {
    "std": 0.0,
    "best_params": {
      "n_components": 8
    },
    "min": 358.264059725745,
    "scores": [
      358.264059725745,
      358.264059725745,
      358.264059725745,
      358.264059725745,
      358.264059725745
    ],
    "mean": 358.264059725745
  },
  "Oracle approximating shrinkage": {
    "std": 0.0,
    "best_params": {
     
    },
    "min": 126.96750876133576,
    "scores": [
      126.96750876133576,
      126.96750876133576,
      126.96750876133576,
      126.96750876133576,
      126.96750876133576
    ],
    "mean": 126.96750876133576
  },
  "Diagonal": {
    "std": 0.0,
    "best_params": {
     
    },
    "min": 186.99828901000086,
    "scores": [
      186.99828901000086,
      186.99828901000086,
      186.99828901000086,
      186.99828901000086,
      186.99828901000086
    ],
    "mean": 186.99828901000086
  },
  "Time-Varying Linear CorEx (WWT)": {
    "std": 0.5034863645611848,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.1,
      "anneal": true,
      "nt": 10,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 98.2091190563992,
    "scores": [
      99.35858859227383,
      98.21227508737329,
      98.2091190563992,
      98.21890126261299,
      99.09543977582987
    ],
    "mean": 98.61886475489784
  },
  "Time-Varying Linear CorEx (W)": {
    "std": 0.11841339622075417,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 1.0,
      "anneal": true,
      "nt": 10,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 98.10453997357055,
    "scores": [
      98.44564261277438,
      98.15173523962295,
      98.2596420391588,
      98.28061573137379,
      98.10453997357055
    ],
    "mean": 98.2484351193001
  },
  "Time-Varying Linear CorEx (MI)": {
    "std": 1.7514553917816653,
    "best_params": {
      "max_iter": 500,
      "l2": 0,
      "l1": 0.3,
      "anneal": true,
      "nt": 10,
      "n_hidden": 8,
      "nv": 128
    },
    "min": 100.12570561441956,
    "scores": [
      105.45838495812738,
      101.75783221241639,
      103.08377261279247,
      102.24871375090159,
      100.12570561441956
    ],
    "mean": 102.53488182973146
  },
  "PCA": {
    "std": 0.0,
    "best_params": {
      "n_components": 8
    },
    "min": 154.51193778733074,
    "scores": [
      154.51193778733074,
      154.51193778733074,
      154.51193778733074,
      154.51193778733074,
      154.51193778733074
    ],
    "mean": 154.51193778733074
  }
}''')

# %%
for k,v in data.items():
    print "{:<40} {:.2f}".format(k, v['mean'])
# Out:
# Ledoit-Wolf                              125.60
# Ground Truth                             84.37
# Time-Varying GLASSO                      97.68
# Time-Varying Linear CorEx (Sigma)        98.53
# Time-Varying GLASSO (no reg)             110.36
# Graphical LASSO                          180.36
# Oracle approximating shrinkage           126.97
# Time-Varying Linear CorEx (W)            98.25
# Time-Varying Linear CorEx (WWT)          98.62
# Diagonal                                 187.00
# Time-Varying Linear CorEx (MI)           102.53
# Linear CorEx                             100.48
# PCA                                      154.51
# Factor Analysis                          358.26
