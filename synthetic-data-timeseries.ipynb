# %%
import numpy as np 
import pandas as pd
import cPickle as pkl
from matplotlib import pyplot as plt
import time

import theano_time_corex
import linearcorex

import random
from scipy.stats import multivariate_normal
import sklearn.covariance as skcov
from sklearn.decomposition import FactorAnalysis

from generate_data import generate_nglf_timeseries

# %% [markdown]
# # Generate Data

# %%
nt = 100
ns = 100
m = 8
nv = m * 8 # 64

(ts_data, test_data, ground_truth) = generate_nglf_timeseries(nv, m, nt, ns, snr=5.0, min_var=1, max_var=1)
# Out:
# Fixed SNR: 5.0
# Fixed SNR: 5.0

# %%
test_data.shape
# Out:
# (100, 100, 64)

# %%
ts_data.shape
# Out:
# (100, 64)

# %% [markdown]
# ### Ground Truth Covariance

# %%
plt.figure(figsize=(8, 8))
plt.title("Sigma1")
plt.imshow(ground_truth[0])
plt.show()
    

plt.figure(figsize=(8, 8))
plt.title("Sigma2")
plt.imshow(ground_truth[-1])
plt.show()

# %% [markdown]
# ### normalize data

# %%
# if diagonal methods work better, maybe normalization can make some problems for them ?
if False:  # if don't need to normalize, as linear corex will do it
    for t in range(nt):
        stds = np.std(Y[t], axis=0)
        X[t] /= stds
        Y[t] /= stds

# %% [markdown]
# ### Sample covariance matrix using test data

# %%
plt.figure(figsize=(8, 8))
plt.title("Empirical covariance at time step 0")
plt.imshow(np.cov(test_data[0].T))
plt.show()

# %% [markdown]
# ### Some functions

# %%
def plot_for_next_timestep(covs, title="Negative log-likelihood of estimate of time step $t$ under the test data of timestep $t + 1$"):
    nll = [-np.mean([multivariate_normal.logpdf(sx, cov=covs[t]) for sx in x]) for x,t in zip(test_data[1:], range(nt-1))]
    plt.bar(range(1, nt), nll, width=0.6)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylim(0)
    plt.ylabel("Negative log-likelihood")
    plt.xticks(range(1, nt))
    plt.show()
    print "NLL for next time step = {}".format(np.mean(nll))
    return np.mean(nll)

# %% [markdown]
# #### Negative log-likelihood of cov. estimate on each timestep. We report the sum of negative log-likelihood over timesteps.

# %%
def calculate_score(covs):
    nll = [-np.mean([multivariate_normal.logpdf(sx, cov=covs[t]) for sx in x]) for x,t in zip(test_data, range(nt))]
    return np.mean(nll)

# %% [markdown]
# # Ground Truth Statistics

# %% [markdown]
# #### This graph shows how well the covariance at timestep t models the test data at timestep t+1. Clearly we should see a peak at the middle timestep.

# %%
if ground_truth[0] is not None:
    plot_for_next_timestep(ground_truth, title="Negative log-likelihood of $\Sigma_t$ under the test data of timestep $t + 1$");
# Out:
# NLL for next time step = 65.1618440649

# %% [markdown]
# #### Negative log-likelihood of cov. estimate on each timestep. We report the sum of negative log-likelihood over timesteps.

# %%
if ground_truth[0] is not None:
    print "Final NLL = {}".format(calculate_score(ground_truth))
# Out:
# Final NLL = 64.9788905803

# %% [markdown]
# # Learn independent linear corexes on each timestep

# %%
length=21

cs = []
for i in range(len(ts_data)):
    left = max(i - length//2, 0)
    data = ts_data[left:left+length]
    c = linearcorex.Corex(n_hidden=m,
                          max_iter=500,
                          anneal=True)
    c.fit(data)
    cs.append(c)
    
print sum([c.tc for c in cs])
# Out:
# 3375.60698223

# %%
cs_covs = [c.get_covariance() for c in cs]

# %%
plt.figure(figsize=(8,8))
plt.imshow(cs_covs[0])
plt.show()

# %%
plot_for_next_timestep(cs_covs);
# Out:
# NLL for next time step = 75.9316788675

# %%
print "Final NLL = {}".format(calculate_score(cs_covs))
# Out:
# Final NLL = 75.9115027366

# %% [markdown]
# # L1 regularization on the difference of neighbouring covariance estimates

# %%
length=21
best_nll = np.inf
best_csig = None
best_l1 = None
coefs = [0, 1e-5, 3e-5, 1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2, 1e-1, 3e-1]
#coefs = [0.01, 0.003, 0.3]
nlls = []
for l1 in coefs:
    
    X = []
    for i in range(len(ts_data)):
        left = max(i-length//2, 0)
        X.append(list(ts_data[left:left+length]))    
    
    print "training with l1 = {}".format(l1)
    csig = theano_time_corex.TimeCorexSigma(nt=nt,
                                            nv=nv,
                                            n_hidden=m,
                                            max_iter=500,
                                            verbose=False,
                                            anneal=True,
                                            l1=l1)
    csig.fit(X)
    csig_covs = csig.get_covariance()
    nll = calculate_score(csig_covs)
    nlls.append(nll)
    print "l1 = {}, nll = {}".format(l1, nll)
    if np.mean(nll) < best_nll:
        best_nll = np.mean(nll)
        best_csig = csig
        best_l1 = l1

print "best l1 = {}".format(best_l1)
csig = best_csig
print sum(csig.tc)
# Out:
# training with l1 = 0
# Annealing iteration finished, time = 35.2688798904
# Annealing iteration finished, time = 35.4118361473
# Annealing iteration finished, time = 35.2833709717
# Annealing iteration finished, time = 35.1376979351
# Annealing iteration finished, time = 35.065639019
# Annealing iteration finished, time = 35.0499489307
# Annealing iteration finished, time = 35.0505731106
# l1 = 0, nll = 75.3042942057
# training with l1 = 1e-05
# Annealing iteration finished, time = 42.3423240185
# Annealing iteration finished, time = 42.6672940254
# Annealing iteration finished, time = 42.6614639759
# Annealing iteration finished, time = 42.8778460026
# Annealing iteration finished, time = 43.095184803
# Annealing iteration finished, time = 42.9371979237
# Annealing iteration finished, time = 42.8473770618
# l1 = 1e-05, nll = 75.3908474727
# training with l1 = 3e-05
# Annealing iteration finished, time = 46.0977060795
# Annealing iteration finished, time = 49.3852069378
# Annealing iteration finished, time = 51.1741731167
# Annealing iteration finished, time = 51.9348459244
# Annealing iteration finished, time = 50.8896429539
# Annealing iteration finished, time = 50.6449770927
# Annealing iteration finished, time = 51.3070700169
# l1 = 3e-05, nll = 75.3459933258
# training with l1 = 0.0001
# Annealing iteration finished, time = 50.6127948761
# Annealing iteration finished, time = 50.1936478615
# Annealing iteration finished, time = 51.3655200005
# Annealing iteration finished, time = 51.0529689789
# Annealing iteration finished, time = 51.5770339966
# Annealing iteration finished, time = 50.6625380516
# Annealing iteration finished, time = 54.0643160343
# l1 = 0.0001, nll = 75.3444421477
# training with l1 = 0.0003
# Annealing iteration finished, time = 51.0665290356
# Annealing iteration finished, time = 94.4754309654
# Annealing iteration finished, time = 115.359620094
# Annealing iteration finished, time = 114.300173044
# Annealing iteration finished, time = 119.885143042
# Annealing iteration finished, time = 119.133846998
# Annealing iteration finished, time = 113.835132837
# l1 = 0.0003, nll = 75.2995742869
# training with l1 = 0.001
# Annealing iteration finished, time = 123.354192019
# Annealing iteration finished, time = 99.895375967
# Annealing iteration finished, time = 49.2901558876
# Annealing iteration finished, time = 48.9152669907
# Annealing iteration finished, time = 48.6299669743
# Annealing iteration finished, time = 49.5923900604
# Annealing iteration finished, time = 49.1891851425
# l1 = 0.001, nll = 75.5326950657
# training with l1 = 0.003
# Annealing iteration finished, time = 148.428941011
# Annealing iteration finished, time = 170.012895107
# Annealing iteration finished, time = 161.732539177
# Annealing iteration finished, time = 161.590450048
# Annealing iteration finished, time = 156.78253293
# Annealing iteration finished, time = 173.88228178
# Annealing iteration finished, time = 184.665630102
# l1 = 0.003, nll = 75.1879137635
# training with l1 = 0.01
# Annealing iteration finished, time = 174.122380972
# Annealing iteration finished, time = 170.448529959
# Annealing iteration finished, time = 188.664226055
# Annealing iteration finished, time = 182.160769939
# Annealing iteration finished, time = 187.256657124
# Annealing iteration finished, time = 173.255953789
# Annealing iteration finished, time = 188.928457022
# l1 = 0.01, nll = 75.3793587956
# training with l1 = 0.03
# Annealing iteration finished, time = 71.2263708115
# Annealing iteration finished, time = 72.3588790894
# Annealing iteration finished, time = 74.2361381054
# Annealing iteration finished, time = 73.0956001282
# Annealing iteration finished, time = 71.0513269901
# Annealing iteration finished, time = 72.4294030666
# Annealing iteration finished, time = 75.164236784
# l1 = 0.03, nll = 77.1791021529
# training with l1 = 0.1
# Annealing iteration finished, time = 76.5275390148
# Annealing iteration finished, time = 81.5959079266
# Annealing iteration finished, time = 91.4611039162
# Annealing iteration finished, time = 186.504296064
# Annealing iteration finished, time = 195.043402195
# Annealing iteration finished, time = 113.286872864
# Annealing iteration finished, time = 118.315502167
# l1 = 0.1, nll = 84.9509511871
# training with l1 = 0.3
# Annealing iteration finished, time = 74.4942879677
# Annealing iteration finished, time = 75.3289399147
# Annealing iteration finished, time = 74.2100448608
# Annealing iteration finished, time = 74.7393019199
# Annealing iteration finished, time = 74.1594049931
# Annealing iteration finished, time = 75.827103138
# Annealing iteration finished, time = 92.5465188026
# l1 = 0.3, nll = 86.5456424846
# best l1 = 0.003
# 3331.0938193

# %%
csig_covs = csig.get_covariance()

# %%
plt.figure(figsize=(8,8))
plt.imshow(csig_covs[0])
plt.show()

# %%
plot_for_next_timestep(csig_covs);
# Out:
# NLL for next time step = 75.2998175721

# %%
print "Final NLL = {}".format(calculate_score(csig_covs))
# Out:
# Final NLL = 75.1879137635

# %% [markdown]
# # Diagonal matrix

# %%
diag_covs = []
for x in X:
    diag_covs.append(np.diag(np.var(x, axis=0)))

# %%
plot_for_next_timestep(diag_covs);
# Out:
# NLL for next time step = 92.9395384565

# %%
print "Final NLL = {}".format(calculate_score(diag_covs))
# Out:
# Final NLL = 92.9539938223

# %% [markdown]
# ## Ledoit-Wolf Estimation

# %%
lw_covs = []
for x in X:
    lw_est = skcov.LedoitWolf()
    lw_est.fit(x)
    lw_covs.append(lw_est.covariance_)

# %%
plot_for_next_timestep(lw_covs);
# Out:
# NLL for next time step = 81.7763276533

# %%
print "Final NLL = {}".format(calculate_score(lw_covs))
# Out:
# Final NLL = 81.7541502564

# %% [markdown]
# ## Oracle Approximating Shrinkage

# %%
oas_covs = []
for x in X:
    oas_est = skcov.OAS()
    oas_est.fit(x)
    oas_covs.append(oas_est.covariance_)

# %%
plot_for_next_timestep(oas_covs);
# Out:
# NLL for next time step = 81.7395378661

# %%
print "Final NLL = {}".format(calculate_score(oas_covs))
# Out:
# Final NLL = 81.7110374568

# %% [markdown]
# # Factor Analysis

# %%
factor_covs = []
for x in X:
    factor_est = FactorAnalysis(n_components=m)
    factor_est.fit(x)
    factor_covs.append(factor_est.get_covariance())

# %%
# factor_covs = [x + 1e-6 * np.eye(nv) for x in factor_covs]

# %%
plot_for_next_timestep(factor_covs);
# Out:
# NLL for next time step = 190.359178369

# %%
print "Final NLL = {}".format(calculate_score(factor_covs))
# Out:
# Final NLL = 39428.6871738

# %% [markdown]
# ## Graphical LASSO

# %%
glasso_covs = []
for x in X:
    glasso_est = skcov.GraphLasso()
    glasso_est.fit(x)
    glasso_covs.append(glasso_est.covariance_)
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-36-37dcd4f61300> in <module>()
#       2 for x in X:
#       3     glasso_est = skcov.GraphLasso()
# ----> 4     glasso_est.fit(x)
#       5     glasso_covs.append(glasso_est.covariance_)
#
# /home/harhrayr/miniconda2/lib/python2.7/site-packages/sklearn/covariance/graph_lasso_.pyc in fit(self, X, y)
#     355             emp_cov, alpha=self.alpha, mode=self.mode, tol=self.tol,
#     356             enet_tol=self.enet_tol, max_iter=self.max_iter,
# --> 357             verbose=self.verbose, return_n_iter=True)
#     358         return self
#     359
#
# /home/harhrayr/miniconda2/lib/python2.7/site-packages/sklearn/covariance/graph_lasso_.pyc in graph_lasso(emp_cov, alpha, cov_init, mode, tol, enet_tol, max_iter, verbose, return_costs, eps, return_n_iter)
#     254         e.args = (e.args[0]
#     255                   + '. The system is too ill-conditioned for this solver',)
# --> 256         raise e
#     257
#     258     if return_costs:
#
# FloatingPointError: Non SPD result: the system is too ill-conditioned for this solver. The system is too ill-conditioned for this solver

# %%
plot_for_next_timestep(glasso_covs);

# %%
print "Final NLL = {}".format(calculate_score(glasso_covs))

# %% [markdown]
# # Summary of the results

# %% [markdown]
# | Model | NLL |
# |:------|----:|
# | ground truth                     | ????????? |
# | independent corexes              | 105237.22 |
# | regularized corex                |  61546.79 |
# | shrinkage estimator (coef = 0.1) | 162136.32 |
# | Ledoit-Wolf                      | 52950.41  |
# | OAS                              | 49325.46  |
# | GLASSO                           | ill cond. |
# | Emprical covariance              | ill cond. |
